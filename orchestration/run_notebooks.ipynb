# %%
import subprocess

notebooks = [
    r"../orchestration/data_loading.ipynb",
    r"../notebooks/01_eda/billings_eda.ipynb",
    r"../notebooks/01_eda/cc_calls_eda.ipynb",
    r"../notebooks/01_eda/emails_eda.ipynb",
    r"../notebooks/01_eda/renewal_calls_eda.ipynb",
    r"../orchestration/interim_data_uploading.ipynb",
    r"../notebooks/02_feature_engineering/01_unique_rows_method/01_combining_filtering.ipynb",
    r"../notebooks/02_feature_engineering/01_unique_rows_method/02_combined_eda.ipynb",
    r"../notebooks/03_modeling/01_train_models.ipynb",
    r"../notebooks/04_evaluation/01_model_evaluation.ipynb",
    r"../notebooks/05_explainability/01_shap_analysis.ipynb",
    r"../notebooks/03_modeling/02_predict_open_prospects.ipynb",
    r"../orchestration/processed_data_uploading.ipynb",
    r"../orchestration/model_uploading.ipynb",
]

for nb in notebooks:
    print(f"Running {nb}...")
    
    result = subprocess.run([
        "jupyter", "nbconvert",
        "--to", "notebook",
        "--execute",
        "--inplace",
        nb
    ])
    
    if result.returncode != 0:
        print(f"Error in {nb}")
        break
    else:
        print(f"Finished {nb}")
# Out:
# Running ../orchestration/data_loading.ipynb...
# Finished ../orchestration/data_loading.ipynb
# Running ../notebooks/01_eda/billings_eda.ipynb...
# Finished ../notebooks/01_eda/billings_eda.ipynb
# Running ../notebooks/01_eda/cc_calls_eda.ipynb...
# Finished ../notebooks/01_eda/cc_calls_eda.ipynb
# Running ../notebooks/01_eda/emails_eda.ipynb...
# Finished ../notebooks/01_eda/emails_eda.ipynb
# Running ../notebooks/01_eda/renewal_calls_eda.ipynb...
# Finished ../notebooks/01_eda/renewal_calls_eda.ipynb
# Running ../orchestration/interim_data_uploading.ipynb...
# Finished ../orchestration/interim_data_uploading.ipynb
# Running ../notebooks/02_feature_engineering/01_unique_rows_method/01_combining_filtering.ipynb...
# Finished ../notebooks/02_feature_engineering/01_unique_rows_method/01_combining_filtering.ipynb
# Running ../notebooks/02_feature_engineering/01_unique_rows_method/02_combined_eda.ipynb...
# ...
